# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
all_merged_no118 = pd.read_csv("C:\\Users\\Sol Joaquin\\Documents\\GitHub\\Coffeeoffers\\all_merged_no118.csv")

# %%
customers_no118_edit = pd.read_csv("C:\\Users\\Sol Joaquin\\Documents\\GitHub\\Coffeeoffers\\customers_no118_edit.csv")

# %%
all_merged_no118.head()
# Out:
#                         customer_id           event  time  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  offer received     0
# 1  e2127556f4f64592b11af22de27a7932  offer received     0
# 2  389bc3fa690240e798340f5a15918d5c  offer received     0
# 3  2eeac8d8feae4a8cad5a6af0499a211d  offer received     0
# 4  aa4862eba776480b8bb9c68455b8c2e1  offer received     0
#
#                            offer id  amount completed offer id  given reward  \
# 0  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN                NaN           NaN
# 1  2906b810c7d4411798c6938adc9daaa5     NaN                NaN           NaN
# 2  f19421c1d4aa40978ebb69ca19b0e20d     NaN                NaN           NaN
# 3  3f207df678b143eea3cee63160fa8bed     NaN                NaN           NaN
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN                NaN           NaN
#
#    transactbeforeoffer  time(days)  rounded day  ...  difficulty  \
# 0                  NaN         0.0          0.0  ...         5.0
# 1                  NaN         0.0          0.0  ...        10.0
# 2                  NaN         0.0          0.0  ...         5.0
# 3                  NaN         0.0          0.0  ...         0.0
# 4                  NaN         0.0          0.0  ...        20.0
#
#   assoc. reward  duration                              channels  \
# 0           5.0       7.0            ['web', 'email', 'mobile']
# 1           2.0       7.0            ['web', 'email', 'mobile']
# 2           5.0       5.0  ['web', 'email', 'mobile', 'social']
# 3           0.0       4.0            ['web', 'email', 'mobile']
# 4           5.0      10.0                      ['web', 'email']
#
#         complete offer  channel 1  channel 2 channel 3 channel 4  \
# 0           bogo-5-5-7        web      email    mobile       NaN
# 1      discount-10-2-7        web      email    mobile       NaN
# 2           bogo-5-5-5        web      email    mobile    social
# 3  informational-0-0-4        web      email    mobile       NaN
# 4     discount-20-5-10        web      email       NaN       NaN
#
#    helper (social)
# 0              0.0
# 1              0.0
# 2              1.0
# 3              0.0
# 4              0.0
#
# [5 rows x 29 columns]

# %%
plt.figure(figsize = (15,1))
sns.boxplot(x=customers_no118_edit['age'], fliersize=1)
plt.title('Boxplot of amount')
# Out:
# Text(0.5, 1.0, 'Boxplot of amount')

# %%
plt.figure(figsize=(30,3))
sns.histplot(x=all_merged_no118['amount'])
plt.xlim(0, 80)
plt.title('Histogram of amount (Beyond 80 USD - not plotted)')
# Out:
# Text(0.5, 1.0, 'Histogram of amount (Beyond 80 USD - not plotted)')

# %%
def boxplot_maker(x):
    sns.boxplot(x=all_merged_no118[x], fliersize=1)
    plt.title('Boxplot of ' + x)
    plt.show()

columns = 'age'
boxplot_maker(columns)

# %%
def boxplot_maker(columns):
    for i in columns:
        plt.figure()
        sns.boxplot(x=customers_no118_edit[i], fliersize=1)
        median = customers_no118_edit[i].median()
        mean = customers_no118_edit[i].mean()
        #plt.axvline(median, color = 'red', linestyle = '--')
        plt.axvline(mean, color = 'green', linestyle = ':')
        #plt.annotate('median',xy = (median,0),arrowprops=dict(arrowstyle = '->', color = 'red', lw = 1.5), color = 'red', fontsize = 8)
        plt.text(
            mean,
            0.5,               # Y position high above boxplot
            f'Mean of {i}',
            ha='center',
            color='red',
            fontsize=10
        )
        plt.ylim(-0.5,0.9)
        plt.title(f'Boxplot of {i}')
        plt.show()
    #plt.title('Boxplot of ' + x)
    #plt.show()

columns = ['age', 'income']
boxplot_maker(columns)

# %%
customers_no118_edit.head()
# Out:
#                         customer_id  became_member_on gender  age    income  \
# 0  0610b486422d4921ae7d2bf64640c50b          20170715      F   55  112000.0
# 1  78afa995795e4d85b5d9ceeca43f5fef          20170509      F   75  100000.0
# 2  e2127556f4f64592b11af22de27a7932          20180426      M   68   70000.0
# 3  389bc3fa690240e798340f5a15918d5c          20180209      M   65   53000.0
# 4  2eeac8d8feae4a8cad5a6af0499a211d          20171111      M   58   51000.0
#
#          date  year  month  total amount transacted  offer completed  \
# 0  2017-07-15  2017      7                    77.01                1
# 1  2017-05-09  2017      5                   159.27                3
# 2  2018-04-26  2018      4                    57.73                2
# 3  2018-02-09  2018      2                    36.43                5
# 4  2017-11-11  2017     11                    15.62                1
#
#    offer received  offer viewed  number of transactions  total events  \
# 0               2             0                       3             6
# 1               4             4                       7            18
# 2               4             3                       3            12
# 3               6             6                       3            20
# 4               3             2                       4            10
#
#    transaction before completed offer
# 0                               23.22
# 1                               41.61
# 2                               18.42
# 3                               36.43
# 4                                7.14
